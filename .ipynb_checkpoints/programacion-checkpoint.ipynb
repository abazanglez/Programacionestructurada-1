# %%
30 + 12
43 - 1
6 * 7
84 / 2
84 // 2
85 // 2
7 ** 2
7 ^ 2

operadores aritmeticos
# Out:
# 5

# %%
30 + 12
# Out:
# 42

# %%
43 - 1
# Out:
# 42

# %%
6 * 7
# Out:
# 42

# %%
84 / 2
# Out:
# 42.0

# %%
84 // 2
# Out:
# 42

# %%
85 // 2
# Out:
# 42

# %%
7 ** 2
# Out:
# 49

# %%
7 ^ 2
# Out:
# 5

# %%
expresiones
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 expresiones
#
# NameError: name 'expresiones' is not defined

# %%
6 + 6 ** 2
# Out:
# 42

# %%
12 + 5 * 6
# Out:
# 42

# %%
(12 + 5) * 6
# Out:
# 102

# %%
""funciones aritmeticas""
round(42.4)
# Out:
#   Cell In[14], line 1
#     ""funciones aritmeticas""
#       ^
# SyntaxError: invalid syntax

# %%
round(42.4)
# Out:
# 42

# %%
round(42.6)
# Out:
# 43

# %%
abs(42)
# Out:
# 42

# %%
abs(-42)
# Out:
# 42

# %%
abs 42
# Out:
#   Cell In[19], line 1
#     abs 42
#         ^
# SyntaxError: invalid syntax

# %%
abs
# Out:
# <function abs(x, /)>

# %%
//cadenas
# Out:
#   Cell In[21], line 1
#     //cadenas
#     ^
# SyntaxError: invalid syntax

# %%
'Hello'
# Out:
# 'Hello'

# %%
"world"
# Out:
# 'world'

# %%
"it's a small "
# Out:
# "it's a small "

# %%
'Well, '
# Out:
# 'Well, '

# %%
'Well, ' + "it's a small " + 'world.'
# Out:
# "Well, it's a small world."

# %%
'Spam, ' * 4
# Out:
# 'Spam, Spam, Spam, Spam, '

# %%
len('Spam')
# Out:
# 4

# %%
`Hello`
# Out:
#   Cell In[29], line 1
#     `Hello`
#     ^
# SyntaxError: invalid syntax

# %%
##valores y tipos

# %%
type(2)
# Out:
# int

# %%
type(42.0)
# Out:
# float

# %%
type('Hello, World!')
# Out:
# str

# %%
int(42.9)
# Out:
# 42

# %%
float(42)
# Out:
# 42.0

# %%
'126'
# Out:
# '126'

# %%
type('126')
# Out:
# str

# %%
'126' / 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 '126' / 3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
int('126') / 3
# Out:
# 42.0

# %%
float('12.6')
# Out:
# 12.6

# %%
1,000,000
# Out:
# (1, 0, 0)

# %%
1_000_000
# Out:
# 1000000

# %%
#lenguajes formales y naturales

# %%
### ejercicios

# %%
round(42.5)
# Out:
# 42

# %%
round(43.5)
# Out:
# 44

# %%
765

2.718

'2 pi'

abs(-7)

abs(-7.0)

abs

int

type
# Out:
# type
